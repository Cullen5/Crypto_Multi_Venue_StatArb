# %%
from strat_a.data_loader import DataLoader
from utilities.term_structure_analysis import TermStructureAnalysis

# %%
dl = DataLoader("./data_collect/data/raw")
ts = TermStructureAnalysis(dl)
ts.run_all()              # prints everything, saves plots
ts.save_report()          # saves figures to ./figures/
# Out:
# DataLoader: data_collect\data\raw
#   Found:   binance_spot, binance_perp, binance_funding, binance_quarterly, binance_contracts, deribit_perp, deribit_funding, deribit_quarterly, hyperliquid_funding, hyperliquid_perp, dydx_funding, dydx_perp
#   Missing: deribit_contracts
#
# ════════════════════════════════════════════════════════════
#   BTC FUTURES TERM STRUCTURE ANALYSIS (Section 3.1)
# ════════════════════════════════════════════════════════════
#
# ────────────────────────────────────────────────────────────
#   1. TRADITIONAL TERM STRUCTURE (CEX Futures)
# ────────────────────────────────────────────────────────────
#   ⚠ Repaired 8760 rows with μs timestamps → ms
#
#   Date range: 2022-01-01 → 2025-06-21
#   Observations: 1264
#
#   Annualised basis (%):
#     Mean:       7.22%
#     Median:     5.86%
#     Std:        5.95%
#     Min:       -8.32%
#     Max:       44.73%
#
#   Contango frequency:      1203/1264 (95.2%)
#   Backwardation frequency: 61/1264 (4.8%)
#
#   Regime distribution:
#     mild_contango         711 days (56.2%)
#     flat                  496 days (39.2%)
#     steep_contango         55 days (4.4%)
#     backwardation           2 days (0.2%)
#
# ────────────────────────────────────────────────────────────
#   2. FUNDING RATE TERM STRUCTURE (On-chain)
# ────────────────────────────────────────────────────────────
#   Loaded binance funding: 4,383 rows
#   Loaded deribit funding: 35,063 rows
#   Loaded hyperliquid funding: 22,590 rows
#   Loaded dydx funding: 19,134 rows
#   Venues available: ['binance', 'deribit', 'hyperliquid', 'dydx']
#
#   Venue              Mean 8h      Ann %     Std 8h      Obs
#   ───────────────────────────────────────────────────────
#   binance           0.000066      7.28%   0.000087     4383
#   deribit           0.000046      5.08%   0.000140     4383
#   hyperliquid       0.000150     16.47%   0.000208     2895
#   dydx              0.000139     15.19%   0.000203     2392
#
#   Pairwise funding differentials (annualised %):
#   Pair                               Mean      Std   t-stat
#   ────────────────────────────────────────────────────────
#   binance − deribit                 2.20%   13.63%   10.70 ***
#   binance − hyperliquid            -8.02%   18.15%  -23.79 ***
#   binance − dydx                   -6.05%   16.49%  -17.94 ***
#   deribit − hyperliquid            -8.11%   19.10%  -22.84 ***
#   deribit − dydx                   -6.56%   18.50%  -17.34 ***
#   hyperliquid − dydx                3.50%   17.06%   10.05 ***
#
#   Implied 30d futures price from funding (vs spot, latest):
#     binance        : $    87,944 (+0.34% over spot)
#     deribit        : $    88,265 (+0.70% over spot)
#     hyperliquid    : $    88,437 (+0.90% over spot)
#     dydx           : $    86,739 (-1.04% over spot)
#
# ────────────────────────────────────────────────────────────
#   3. CROSS-VENUE BASIS ANALYSIS
# ────────────────────────────────────────────────────────────
#
#   CEX Futures basis vs venue funding rates:
#   Venue                    Corr  Mean Diff  Futures Leads
#   ───────────────────────────────────────────────────────
#   binance                0.686     -0.31% binance→futures
#   deribit                0.535      2.31% deribit→futures
#   hyperliquid            0.654     -7.99% hyperliquid→futures
#   dydx                   0.729     -6.12%   futures→dydx
#
#   Cross-venue basis spreads (annualised %):
#   Pair                               Mean   Median      Std  % Positive
#   ────────────────────────────────────────────────────────────────────
#   binance − deribit                 2.20%    2.58%   11.32%      64.4%
#   binance − hyperliquid            -8.02%   -5.60%   15.75%      18.5%
#   binance − dydx                   -6.03%   -4.43%   14.76%      32.1%
#   deribit − hyperliquid            -8.11%   -6.87%   16.61%      23.7%
#   deribit − dydx                   -6.53%   -4.68%   16.43%      31.2%
#   hyperliquid − dydx                3.54%    2.36%   13.90%      61.4%
#
# ────────────────────────────────────────────────────────────
#   4. LIQUIDITY ANALYSIS
# ────────────────────────────────────────────────────────────
#
#   No futures volume data; using funding observation density as proxy.
#
#   Funding data coverage by venue:
#   Venue            Total Obs  Coverage %  Gaps >1d
#   ────────────────────────────────────────────────
#   binance               4383     100.0%         0
#   deribit               4383     100.0%         0
#   hyperliquid           2895      66.1%         0
#   dydx                  2392      54.6%         0
#
#   Funding rate observation distribution by hour (UTC):
#     00:00  ██████████████████████████████ 1461
#     08:00  ██████████████████████████████ 1461
#     16:00  ██████████████████████████████ 1461
#
# ────────────────────────────────────────────────────────────
#   5. REGIME CLASSIFICATION
# ────────────────────────────────────────────────────────────
#
#   Regime distribution by venue/source:
#   Source                Steep Cont.  Mild Cont.     Flat   Backw.
#   ──────────────────────────────────────────────────────────────
#   binance                 63 ( 4.3%)   828 (56.7%)  543 (37.2%)   27 ( 1.8%)
#   deribit                124 ( 8.5%)   391 (26.8%)  886 (60.6%)   60 ( 4.1%)
#   hyperliquid            246 (16.8%)   561 (38.4%)  597 (40.9%)   57 ( 3.9%)
#   dydx                   210 (14.4%)   356 (24.4%)  850 (58.2%)   45 ( 3.1%)
#   futures                 55 ( 4.4%)   711 (56.2%)  496 (39.2%)    2 ( 0.2%)
#
#   Regime agreement between venues:
#     binance vs deribit: 51.8% agreement (1461 obs)
#     binance vs hyperliquid: 43.1% agreement (1461 obs)
#     binance vs dydx: 43.5% agreement (1461 obs)
#     binance vs futures: 62.2% agreement (1264 obs)
#     deribit vs hyperliquid: 52.5% agreement (1461 obs)
#     deribit vs dydx: 58.1% agreement (1461 obs)
#     deribit vs futures: 54.7% agreement (1264 obs)
#     hyperliquid vs dydx: 67.4% agreement (1461 obs)
#     hyperliquid vs futures: 61.6% agreement (1264 obs)
#     dydx vs futures: 58.8% agreement (1264 obs)
#
# ════════════════════════════════════════════════════════════
#   RESEARCH QUESTIONS
# ════════════════════════════════════════════════════════════
#
#   Q1: Does Hyperliquid funding lead/lag Binance?
#     Peak cross-correlation at lag=0 (0h): r=0.637
#     → Contemporaneous (no clear lead/lag)
#
#   Q2: Are CME futures priced differently (regulation premium)?
#     Futures basis − Deribit funding: +2.31% ann (mean)
#     Interpretation: Futures trade at premium (institutional demand)
#
#   Q3: Can on-chain funding predict futures curve shape?
#     binance funding → next-day futures basis: r=0.683, R²=0.467
#     deribit funding → next-day futures basis: r=0.531, R²=0.282
#     hyperliquid funding → next-day futures basis: r=0.652, R²=0.425
#     dydx funding → next-day futures basis: r=0.714, R²=0.510
#     → Best predictor: dydx (R²=0.510)
#
#   Q4: How does GMX fit into term structure analysis?
#     GMX data not available in funding comparison.
#     Note: GMX uses borrow fees rather than funding rates,
#     making direct comparison difficult. GMX fees are
#     typically higher and less correlated with CEX funding.
#
#   Q5: During what regimes do cross-venue opportunities appear?
#
#     binance-deribit spread by regime:
#       backwardation       : mean=  -3.5%, |spread|>10% on 32% of days
#       flat                : mean=   0.4%, |spread|>10% on 11% of days
#       mild_contango       : mean=   3.3%, |spread|>10% on 35% of days
#       steep_contango      : mean=   7.5%, |spread|>10% on 67% of days
#
#     binance-hyperliquid spread by regime:
#       backwardation       : mean= -13.4%, |spread|>10% on 81% of days
#       flat                : mean=  -6.2%, |spread|>10% on 37% of days
#       mild_contango       : mean=  -7.0%, |spread|>10% on 34% of days
#       steep_contango      : mean= -26.4%, |spread|>10% on 75% of days
#
#     binance-dydx spread by regime:
#       backwardation       : mean= -11.0%, |spread|>10% on 60% of days
#       flat                : mean=  -3.9%, |spread|>10% on 33% of days
#       mild_contango       : mean=  -4.9%, |spread|>10% on 47% of days
#       steep_contango      : mean= -23.2%, |spread|>10% on 80% of days
#
#     deribit-hyperliquid spread by regime:
#       backwardation       : mean= -22.1%, |spread|>10% on 91% of days
#       flat                : mean=  -8.3%, |spread|>10% on 49% of days
#       mild_contango       : mean=  -7.1%, |spread|>10% on 34% of days
#       steep_contango      : mean=  -7.3%, |spread|>10% on 71% of days
#
#     deribit-dydx spread by regime:
#       backwardation       : mean= -19.8%, |spread|>10% on 66% of days
#       flat                : mean=  -7.0%, |spread|>10% on 38% of days
#       mild_contango       : mean=  -5.5%, |spread|>10% on 40% of days
#       steep_contango      : mean=  -4.7%, |spread|>10% on 63% of days
#
#     hyperliquid-dydx spread by regime:
#       backwardation       : mean= -14.3%, |spread|>10% on 61% of days
#       flat                : mean=  -1.7%, |spread|>10% on 28% of days
#       mild_contango       : mean=   1.6%, |spread|>10% on 34% of days
#       steep_contango      : mean=  12.2%, |spread|>10% on 69% of days
#
#     → Cross-venue opportunities are most frequent during steep contango
#       and backwardation regimes (extremes).
#
# ════════════════════════════════════════════════════════════
#   ANALYSIS COMPLETE
# ════════════════════════════════════════════════════════════
#
#   Saving plots to ./figures/...
#     01a_spot_vs_futures.png
#     01b_basis_regimes.png
#     02_funding_rates.png
#     03_cross_venue_spreads.png
#     04_data_coverage.png
#     05_regimes.png
#     06_basis_distribution.png
#     07_lead_lag_xcorr.png
#   Done.
#
#   Saving plots to ./figures/...
#     01a_spot_vs_futures.png
#     01b_basis_regimes.png
#     02_funding_rates.png
#     03_cross_venue_spreads.png
#     04_data_coverage.png
#     05_regimes.png
#     06_basis_distribution.png
#     07_lead_lag_xcorr.png
#   Done.
